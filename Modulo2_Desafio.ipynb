# %% [markdown]
# <a href="https://colab.research.google.com/github/danielaolage/machineLearning/blob/master/Modulo2_Desafio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#notebook utilizado para a disciplina de MPT para o bootcamp de machine learning: Desafio

# %%
#importando os dados para o google colab
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-387af7cb-d516-4fc6-b036-f57f889e53ac" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-387af7cb-d516-4fc6-b036-f57f889e53ac">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving winequality-red.csv to winequality-red.csv

# %%
#importando as bibliotecas
import pandas as pd  #bibioteca responsável para o tratamento e limpeza dos dados
import numpy as np #biblioteca utilizada para o tratamento eficiente de dados numéricos
import datetime  #biblioteca utilizada para trabalhar com datas
from matplotlib import pyplot as plt  #plotar os gráficos
import seaborn as sns #plot de gráficos
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
#carregando os dados para o pandas
df_consultas=pd.read_csv('winequality-red.csv', sep = ';')

# %%
#mostrando as características do dataset
df_consultas.head(15)
# Out:
#     fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0             7.4             0.700         0.00  ...       0.56      9.4        5
# 1             7.8             0.880         0.00  ...       0.68      9.8        5
# 2             7.8             0.760         0.04  ...       0.65      9.8        5
# 3            11.2             0.280         0.56  ...       0.58      9.8        6
# 4             7.4             0.700         0.00  ...       0.56      9.4        5
# 5             7.4             0.660         0.00  ...       0.56      9.4        5
# 6             7.9             0.600         0.06  ...       0.46      9.4        5
# 7             7.3             0.650         0.00  ...       0.47     10.0        7
# 8             7.8             0.580         0.02  ...       0.57      9.5        7
# 9             7.5             0.500         0.36  ...       0.80     10.5        5
# ...

# %%
#mostrando as dimensões do dataset
df_consultas.shape
# Out:
# (1599, 12)

# %%
#mostrando as "características" das colunas
df_consultas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
#contando a quantidade de valores nulos
df_consultas.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
#proporção de valores nulos para variavel residual sugar
df_consultas['residual sugar'].isnull().sum()/len(df_consultas)
# Out:
# 0.0

# %%
#analisando as "estatísticas do dataset"
df_consultas.describe()
# Out:
#        fixed acidity  volatile acidity  ...      alcohol      quality
# count    1599.000000       1599.000000  ...  1599.000000  1599.000000
# mean        8.319637          0.527821  ...    10.422983     5.636023
# std         1.741096          0.179060  ...     1.065668     0.807569
# min         4.600000          0.120000  ...     8.400000     3.000000
# 25%         7.100000          0.390000  ...     9.500000     5.000000
# 50%         7.900000          0.520000  ...    10.200000     6.000000
# 75%         9.200000          0.640000  ...    11.100000     6.000000
# max        15.900000          1.580000  ...    14.900000     8.000000
#
# [8 rows x 12 columns]

# %%
#correlação
df_consultas['pH'].corr(df_consultas['fixed acidity'])
# Out:
# -0.6829781945685316

# %%
#define o método a ser usado na correlação das variáveis
df_consultas.corr(method = 'pearson')
# Out:
#                       fixed acidity  volatile acidity  ...   alcohol   quality
# fixed acidity              1.000000         -0.256131  ... -0.061668  0.124052
# volatile acidity          -0.256131          1.000000  ... -0.202288 -0.390558
# citric acid                0.671703         -0.552496  ...  0.109903  0.226373
# residual sugar             0.114777          0.001918  ...  0.042075  0.013732
# chlorides                  0.093705          0.061298  ... -0.221141 -0.128907
# free sulfur dioxide       -0.153794         -0.010504  ... -0.069408 -0.050656
# total sulfur dioxide      -0.113181          0.076470  ... -0.205654 -0.185100
# density                    0.668047          0.022026  ... -0.496180 -0.174919
# pH                        -0.682978          0.234937  ...  0.205633 -0.057731
# sulphates                  0.183006         -0.260987  ...  0.093595  0.251397
# alcohol                   -0.061668         -0.202288  ...  1.000000  0.476166
# ...

# %%
#correlação
df_consultas['alcohol'].corr(df_consultas['quality'])
# Out:
# 0.47616632400113584

# %%
#correlação exibida com cores
df_consultas.corr().style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# Out:
# <style  type="text/css" >
#     #T_dfa246ca_d794_11ea_98d7_0242ac1c0002row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_dfa246ca_d794_11ea_98d7_0242ac1c0002row0_col1 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_dfa246ca_d794_11ea_98d7_0242ac1c0002row0_col2 {
#             background-color:  #ec8165;
#             color:  #000000;
#         }    #T_dfa246ca_d794_11ea_98d7_0242ac1c0002row0_col3 {
#             background-color:  #d6dce4;
#             color:  #000000;
#         }    #T_dfa246ca_d794_11ea_98d7_0242ac1c0002row0_col4 {
#             background-color:  #d3dbe7;
#             color:  #000000;
#         }    #T_dfa246ca_d794_11ea_98d7_0242ac1c0002row0_col5 {
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }    #T_dfa246ca_d794_11ea_98d7_0242ac1c0002row0_col6 {
#             background-color:  #abc8fd;
#             color:  #000000;
# ...

# %%
#quantidade de instancias do atributo quality com valor igual a 5
df_consultas['quality'].value_counts()[5]
# Out:
# 681

# %%
#aplicando um modelo de normalização 
from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler()
